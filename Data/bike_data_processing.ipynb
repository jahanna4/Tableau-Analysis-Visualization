# %%
import pandas as pd
# import csv

# %%
june_data = "202006-citibike-tripdata.csv"
may_data = "202005-citibike-tripdata.csv"
april_data = "202004-citibike-tripdata.csv"

# %%
june_df = pd.read_csv(june_data)
may_df = pd.read_csv(may_data)
april_df = pd.read_csv(april_data)
# june_df.head()
# may_df.head()
april_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           534  2020-04-01 00:00:15.2800  2020-04-01 00:09:09.8730
# 1           529  2020-04-01 00:02:28.9430  2020-04-01 00:11:18.3410
# 2          1488  2020-04-01 00:02:56.0900  2020-04-01 00:27:44.2530
# 3           341  2020-04-01 00:03:25.1410  2020-04-01 00:09:06.3190
# 4          2206  2020-04-01 00:05:35.2790  2020-04-01 00:42:21.9080
#
#    start station id           start station name  start station latitude  \
# 0              3656            E 2 St & Avenue A               40.723077
# 1              3163  Central Park West & W 68 St               40.773407
# 2              3164       Columbus Ave & W 72 St               40.777057
# 3              3827         Halsey St & Broadway               40.685650
# 4              3890          Grove St & Broadway               40.690470
#
#    start station longitude  end station id           end station name  \
# ...

# %%
june_df.shape
# Out:
# (1882273, 15)

# %%
may_df.shape
# Out:
# (1487890, 15)

# %%
april_df.shape
# Out:
# (682762, 15)

# %%
testsum = (1882273+1487890+682762)
print(f"final data should have {testsum} rows")
# Out:
# final data should have 4052925 rows

# %%
all_data = [june_df, may_df, april_df]

# %%
fulldata = pd.concat(all_data)

# %%
fulldata
# Out:
#         tripduration                 starttime                  stoptime  \
# 0               1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1               3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2               1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3                226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4               1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
# ...              ...                       ...                       ...
# 682757          1680  2020-04-30 23:59:00.7780  2020-05-01 00:27:01.7600
# 682758          1334  2020-04-30 23:59:23.6460  2020-05-01 00:21:38.2190
# 682759          1334  2020-04-30 23:59:33.6760  2020-05-01 00:21:48.2150
# 682760           234  2020-04-30 23:59:56.9720  2020-05-01 00:03:51.9600
# 682761           267  2020-04-30 23:59:59.3510  2020-05-01 00:04:26.8110
#
#         start station id        start station name  start station latitude  \
# ...

# %%
fulldata.to_csv("202004_202006_data")
